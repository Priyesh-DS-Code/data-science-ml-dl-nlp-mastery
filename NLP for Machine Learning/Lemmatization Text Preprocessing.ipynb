# %% [markdown]
# ## Lemmatizer

# %% [markdown]
# * Q&A
# * Chatbots
# * Text Summarization

# %%
import nltk

# nltk.download('wordnet')
# nltk.download('omw-1.4')

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# %%
'''
lemmatize(word, pos)    ## by default pos='n'

pos-
noun-n
verb-v
adjective-a
adverb-r
'''

lemmatizer.lemmatize("going")
# Out:
# 'going'

# %%
words = ['eating', 'eats', 'eaten', 'writting', 'writes', 'programming', 'programs', 'history', 'finally', 'finalized']

for word in words:
    print(word + "---->" + lemmatizer.lemmatize(word))
# Out:
# eating---->eating
# eats---->eats
# eaten---->eaten
# writting---->writting
# writes---->writes
# programming---->programming
# programs---->program
# history---->history
# finally---->finally
# finalized---->finalized

# %%
for word in words:
    print(word + "---->" + lemmatizer.lemmatize(word, pos='v'))
# Out:
# eating---->eat
# eats---->eat
# eaten---->eat
# writting---->writting
# writes---->write
# programming---->program
# programs---->program
# history---->history
# finally---->finally
# finalized---->finalize

# %%
lemmatizer.lemmatize('fairly', pos='v'), lemmatizer.lemmatize('sportingly')
# Out:
# ('fairly', 'sportingly')
